# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# '/Users/griffinmccauley/Desktop/SARC 5400/Ugly Sketch & Prototype/Data'

# %%
df = pd.read_csv(f'{os.getcwd()}/gdp.csv').dropna().iloc[:,2:]
df = df[df[df.columns[2]] != '..']
df = df.astype({df.columns[2]: float})
df = df.sort_values(by=[df.columns[2]], ascending=False)
gdp = df.iloc[:10,:].rename(columns = {df.columns[2]: 'GDP'})
gdp
# Out:
#        Country Name Country Code           GDP
# 206   United States          USA  2.331508e+13
# 41            China          CHN  1.773406e+13
# 98            Japan          JPN  4.940878e+12
# 73          Germany          DEU  4.259935e+12
# 89            India          IND  3.176295e+12
# 205  United Kingdom          GBR  3.131378e+12
# 68           France          FRA  2.957880e+12
# 96            Italy          ITA  2.107703e+12
# 35           Canada          CAN  1.988336e+12
# 104     Korea, Rep.          KOR  1.810956e+12

# %%
df = pd.read_csv(f'{os.getcwd()}/imports.csv').dropna().iloc[:,2:]
df = df[df[df.columns[2]] != '..']
df = df.astype({df.columns[2]: float})
df = df.sort_values(by=[df.columns[2]], ascending=False)
imports = df.drop(columns=[df.columns[1]]).rename(columns = {df.columns[2]: 'Imports'})
imports
# Out:
#               Country Name       Imports
# 206          United States  3.401361e+12
# 41                   China  3.091259e+12
# 73                 Germany  1.776914e+12
# 98                   Japan  9.364105e+11
# 68                  France  9.285055e+11
# ..                     ...           ...
# 195                  Tonga  2.855029e+08
# 128  Micronesia, Fed. Sts.  2.815000e+08
# 102               Kiribati  1.983173e+08
# 124       Marshall Islands  1.807270e+08
# 137                  Nauru  1.418016e+08
#
# [166 rows x 2 columns]

# %%
df = pd.read_csv(f'{os.getcwd()}/exports.csv').dropna().iloc[:,2:]
df = df[df[df.columns[2]] != '..']
df = df.astype({df.columns[2]: float})
df = df.sort_values(by=[df.columns[2]], ascending=False)
exports = df.drop(columns=[df.columns[1]]).rename(columns = {df.columns[2]: 'Exports'})
exports
# Out:
#               Country Name       Exports
# 41                   China  3.553509e+12
# 206          United States  2.539648e+12
# 73                 Germany  2.003471e+12
# 98                   Japan  9.104890e+11
# 205         United Kingdom  8.751969e+11
# ..                     ...           ...
# 128  Micronesia, Fed. Sts.  9.630000e+07
# 209                Vanuatu  9.428748e+07
# 195                  Tonga  5.876026e+07
# 137                  Nauru  5.448168e+07
# 102               Kiribati  2.629207e+07
#
# [166 rows x 2 columns]

# %%
df = pd.read_csv(f'{os.getcwd()}/emissions.csv').dropna().iloc[:,2:-2]
df.dtypes
df = df[df[df.columns[2]] != '..']
df = df[df[df.columns[3]] != '..']
df = df[df[df.columns[4]] != '..']
df = df[df[df.columns[5]] != '..']
df = df[df[df.columns[6]] != '..']
df = df[df[df.columns[7]] != '..']
df = df[df[df.columns[8]] != '..']
df = df[df[df.columns[9]] != '..']
df = df[df[df.columns[10]] != '..']
df = df[df[df.columns[11]] != '..']
df = df[df[df.columns[12]] != '..']
df = df[df[df.columns[13]] != '..']
df = df[df[df.columns[14]] != '..']
df = df[df[df.columns[15]] != '..']
df = df[df[df.columns[16]] != '..']
df = df[df[df.columns[17]] != '..']
df = df.astype({df.columns[2]: float, df.columns[3]: float, df.columns[4]: float, df.columns[5]: float, 
                df.columns[6]: float, df.columns[7]: float, df.columns[8]: float, df.columns[9]: float, 
                df.columns[10]: float, df.columns[11]: float, df.columns[12]: float, df.columns[13]: float, 
                df.columns[14]: float, df.columns[15]: float, df.columns[16]: float, df.columns[17]: float})
emissions = df.drop(columns=[df.columns[1]])
emissions
# Out:
#       Country Name  1990 [YR1990]  2005 [YR2005]  2006 [YR2006]  \
# 0    United States      4844520.0   5.753490e+06   5.653080e+06
# 1      Afghanistan         2380.0   1.550000e+03   1.760000e+03
# 2          Albania         5980.0   4.030000e+03   4.010000e+03
# 3          Algeria        62940.0   9.419000e+04   9.981000e+04
# 5          Andorra          410.0   5.800000e+02   5.500000e+02
# ..             ...            ...            ...            ...
# 210  Venezuela, RB       101630.0   1.473800e+05   1.475300e+05
# 211        Vietnam        19330.0   9.237000e+04   9.487000e+04
# 214    Yemen, Rep.         6640.0   2.111000e+04   2.192000e+04
# 215         Zambia         2740.0   2.290000e+03   2.180000e+03
# 216       Zimbabwe        16540.0   1.051000e+04   9.830000e+03
#
#      2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  2010 [YR2010]  \
# 0     5.736320e+06   5.558380e+06   5.156430e+06   5.392110e+06
# 1     1.770000e+03   3.560000e+03   4.880000e+03   7.110000e+03
# ...

# %%
#pd.read_excel(f'{os.getcwd()}/trade.xlsx','Partner').dropna().iloc[:,:11]

# %%
data = gdp.merge(imports, how='inner', on='Country Name').merge(exports, how='inner', on='Country Name').merge(emissions, how='inner', on='Country Name')
data
# Out:
#      Country Name Country Code           GDP       Imports       Exports  \
# 0   United States          USA  2.331508e+13  3.401361e+12  2.539648e+12
# 1           China          CHN  1.773406e+13  3.091259e+12  3.553509e+12
# 2           Japan          JPN  4.940878e+12  9.364105e+11  9.104890e+11
# 3         Germany          DEU  4.259935e+12  1.776914e+12  2.003471e+12
# 4           India          IND  3.176295e+12  7.588719e+11  6.796806e+11
# 5  United Kingdom          GBR  3.131378e+12  8.993653e+11  8.751969e+11
# 6          France          FRA  2.957880e+12  9.285055e+11  8.710587e+11
# 7           Italy          ITA  2.107703e+12  6.389147e+11  6.885824e+11
# 8          Canada          CAN  1.988336e+12  6.091858e+11  6.111214e+11
# 9     Korea, Rep.          KOR  1.810956e+12  6.964365e+11  7.612443e+11
#
#    1990 [YR1990]  2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  \
# 0      4844520.0   5.753490e+06   5.653080e+06   5.736320e+06   5.558380e+06
# ...

# %%
data['reduction'] = [.49,1,.54,.45,.55,1,.45,.45,.575,1]

# %%
data['Target'] = data[data.columns[6]]*data['reduction']
data['Target']
# Out:
# 0    2.819210e+06
# 1    5.824630e+06
# 2    6.549228e+05
# 3    3.610710e+05
# 4    6.250585e+05
# 5    5.409200e+05
# 6    1.712970e+05
# 7    2.132235e+05
# 8    3.156923e+05
# 9    4.810000e+05
# Name: Target, dtype: float64

# %%
CHN = ((5.824630e+06)/2285965892360.5)*.35*1.773406e+13
KOR = .6*6.306400e+05
GBR = .32*561770.0

# %%
data.loc[data['Country Code'] == 'CHN','Target'] = CHN
data.loc[data['Country Code'] == 'KOR','Target'] = KOR
data.loc[data['Country Code'] == 'GBR','Target'] = GBR
data['Target']
# Out:
# 0    2.819210e+06
# 1    1.581520e+07
# 2    6.549228e+05
# 3    3.610710e+05
# 4    6.250585e+05
# 5    1.797664e+05
# 6    1.712970e+05
# 7    2.132235e+05
# 8    3.156923e+05
# 9    3.783840e+05
# Name: Target, dtype: float64

# %%
data.drop(columns=['reduction','1990 [YR1990]'], inplace=True)
data['Current Emissions'] = data['2019 [YR2019]']
data['Continent'] = ['North America', 'Asia', 'Asia', 'Europe', 'Asia', 'Europe', 'Europe', 'Europe', 'North America', 'Asia']
data
# Out:
#      Country Name Country Code           GDP       Imports       Exports  \
# 0   United States          USA  2.331508e+13  3.401361e+12  2.539648e+12
# 1           China          CHN  1.773406e+13  3.091259e+12  3.553509e+12
# 2           Japan          JPN  4.940878e+12  9.364105e+11  9.104890e+11
# 3         Germany          DEU  4.259935e+12  1.776914e+12  2.003471e+12
# 4           India          IND  3.176295e+12  7.588719e+11  6.796806e+11
# 5  United Kingdom          GBR  3.131378e+12  8.993653e+11  8.751969e+11
# 6          France          FRA  2.957880e+12  9.285055e+11  8.710587e+11
# 7           Italy          ITA  2.107703e+12  6.389147e+11  6.885824e+11
# 8          Canada          CAN  1.988336e+12  6.091858e+11  6.111214e+11
# 9     Korea, Rep.          KOR  1.810956e+12  6.964365e+11  7.612443e+11
#
#    2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  \
# 0   5.753490e+06   5.653080e+06   5.736320e+06   5.558380e+06   5.156430e+06
# ...

# %%
data.to_csv(f'{os.getcwd()}/data.csv', index=False)

# %%
pd.read_csv(f'{os.getcwd()}/data.csv')
# Out:
#      Country Name Country Code           GDP       Imports       Exports  \
# 0   United States          USA  2.331508e+13  3.401361e+12  2.539648e+12
# 1           China          CHN  1.773406e+13  3.091259e+12  3.553509e+12
# 2           Japan          JPN  4.940878e+12  9.364105e+11  9.104890e+11
# 3         Germany          DEU  4.259935e+12  1.776914e+12  2.003471e+12
# 4           India          IND  3.176295e+12  7.588719e+11  6.796806e+11
# 5  United Kingdom          GBR  3.131378e+12  8.993653e+11  8.751969e+11
# 6          France          FRA  2.957880e+12  9.285055e+11  8.710587e+11
# 7           Italy          ITA  2.107703e+12  6.389147e+11  6.885824e+11
# 8          Canada          CAN  1.988336e+12  6.091858e+11  6.111214e+11
# 9     Korea, Rep.          KOR  1.810956e+12  6.964365e+11  7.612443e+11
#
#    2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  \
# 0   5.753490e+06   5.653080e+06   5.736320e+06   5.558380e+06   5.156430e+06
# ...

# %%
# p_table = pd.pivot_table(data, index = [data.columns[5], data.columns[6], data.columns[7], data.columns[8],
#                                         data.columns[9], data.columns[10], data.columns[11], data.columns[12],
#                                         data.columns[13], data.columns[14], data.columns[15], data.columns[16],
#                                         data.columns[17], data.columns[18], data.columns[19]])
# p_table

# %%
full_trade = pd.DataFrame()
countries = ['United States','China','Japan','Germany','India','United Kingdom','France','Italy','Canada', 'Korea, Rep.']
files = ['usa','china','japan','germany','india','uk','france','italy','canada','korea']
for file in files:
    trade = pd.read_excel(f'{os.getcwd()}/trade/{file}.xlsx','Partner').iloc[:,:13]
    trade = trade[trade['Partner Name'].isin(countries)]
    trade = pd.concat([trade.iloc[:,:2], trade.iloc[:,-5:]], axis=1)
    x = trade.sort_values(by=[trade.columns[3]], ascending=False).iloc[:3,:]
    x = pd.concat([x.iloc[:,:2], x.iloc[:,3]], axis=1)
    m = trade.sort_values(by=[trade.columns[4]], ascending=False).iloc[:3,:]
    m = pd.concat([m.iloc[:,:2], m.iloc[:,4]], axis=1)
    # mx = pd.concat([m,x], axis=1)
    # mx = pd.concat([mx.iloc[:,:3], mx.iloc[:,-2:]], axis=1)
    # mx.columns = ['Country','Importer','Imports','Exporter','Exports']
    #full_trade = full_trade.append([mx])
    full_trade = full_trade.append([m,x])
full_trade
# Out:
# /var/folders/_5/sprlgz1x0g5gzbxy4kkfq7r40000gn/T/ipykernel_54130/2397599381.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   full_trade = full_trade.append([m,x])
# /var/folders/_5/sprlgz1x0g5gzbxy4kkfq7r40000gn/T/ipykernel_54130/2397599381.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   full_trade = full_trade.append([m,x])
# /var/folders/_5/sprlgz1x0g5gzbxy4kkfq7r40000gn/T/ipykernel_54130/2397599381.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   full_trade = full_trade.append([m,x])
# /var/folders/_5/sprlgz1x0g5gzbxy4kkfq7r40000gn/T/ipykernel_54130/2397599381.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
full_trade.to_csv(f'{os.getcwd()}/trade.csv', index=False)

# %%
pd.read_csv(f'{os.getcwd()}/trade.csv')
# Out:
#      Reporter Name    Partner Name  Import (US$ Thousand)  \
# 0    United States           China           4.571642e+08
# 1    United States          Canada           2.761955e+08
# 2    United States           Japan           1.224840e+08
# 3    United States          Canada                    NaN
# 4    United States           China                    NaN
# 5    United States           Japan                    NaN
# 6            China           Japan           1.746552e+08
# 7            China     Korea, Rep.           1.731002e+08
# 8            China   United States           1.363395e+08
# 9            China   United States                    NaN
# 10           China           Japan                    NaN
# 11           China     Korea, Rep.                    NaN
# 12           Japan           China           1.638506e+08
# 13           Japan   United States           7.176726e+07
# 14           Japan     Korea, Rep.           2.659951e+07
# ...

# %%
# trade matrix
trade_matrix_x = pd.DataFrame()
trade_matrix_m = pd.DataFrame()
countries = ['United States','China','Japan','Germany','India','United Kingdom','France','Italy','Canada', 'Korea, Rep.']
files = ['usa','china','japan','germany','india','uk','france','italy','canada','korea']
for i, file in enumerate(files):
    trade = pd.read_excel(f'{os.getcwd()}/trade/{file}.xlsx','Partner').iloc[:,:13]
    trade = trade[trade['Partner Name'].isin(countries)]
    trade = pd.concat([trade.iloc[:,:2], trade.iloc[:,-5:]], axis=1)
    
    x = []
    m = []
    for j, country in enumerate(countries):
        if (i == j):
            x.append(0)
            m.append(0)
        else:
            x.append(trade[trade['Partner Name'] == country]['Export (US$ Thousand)'].item())
            m.append(trade[trade['Partner Name'] == country]['Import (US$ Thousand)'].item())
    trade_matrix_x = trade_matrix_x.append([x])
    trade_matrix_m = trade_matrix_m.append([m])
            
trade_matrix_x = trade_matrix_x.to_numpy()
trade_matrix_m = trade_matrix_m.to_numpy().T
trade_matrix = pd.DataFrame((trade_matrix_x + trade_matrix_m)/2)
trade_matrix
# Out:
# /var/folders/_5/sprlgz1x0g5gzbxy4kkfq7r40000gn/T/ipykernel_10043/3353227026.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   trade_matrix_x = trade_matrix_x.append([x])
# /var/folders/_5/sprlgz1x0g5gzbxy4kkfq7r40000gn/T/ipykernel_10043/3353227026.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   trade_matrix_m = trade_matrix_m.append([m])
# /var/folders/_5/sprlgz1x0g5gzbxy4kkfq7r40000gn/T/ipykernel_10043/3353227026.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   trade_matrix_x = trade_matrix_x.append([x])
# ...

# %%
trade_matrix.to_csv(f'{os.getcwd()}/trade_matrix.csv', index=False)

# %%
pd.read_csv(f'{os.getcwd()}/trade_matrix.csv')
# Out:
#               0             1             2             3             4  \
# 0  0.000000e+00  1.304940e+08  6.792898e+07  6.778302e+07  2.700497e+07
# 1  4.548285e+08  0.000000e+00  1.532236e+08  1.108630e+08  6.275915e+07
# 2  1.206386e+08  1.580272e+08  0.000000e+00  2.102578e+07  9.655001e+06
# 3  1.182961e+08  1.077415e+08  2.061414e+07  0.000000e+00  1.097370e+07
# 4  5.144395e+07  1.999278e+07  4.384980e+06  8.991609e+06  0.000000e+00
# 5  5.322403e+07  1.919211e+07  6.777318e+06  4.053001e+07  4.318648e+06
# 6  4.047718e+07  2.483615e+07  7.869221e+06  6.711492e+07  3.910796e+06
# 7  4.973486e+07  1.846381e+07  9.300048e+06  6.281650e+07  3.576590e+06
# 8  2.803365e+08  2.046225e+07  1.002300e+07  5.055112e+06  2.756423e+06
# 9  7.634402e+07  1.528276e+08  2.584598e+07  1.112855e+07  1.206056e+07
#
#               5             6             7             8             9
# 0  5.859858e+07  2.809258e+07  1.840179e+07  2.263748e+08  5.448865e+07
# ...
